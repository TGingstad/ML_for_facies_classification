# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['seis_inv_p', 'relai_p', 'rms_p', 'domfreq_p', 'seis_inv_s', 'relai_s', 'rms_s', 'domfreq_s']
A = ML_classification(features, well_line='W0', resolution='low', facies='normal')
A.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[21  2  6  0  0]
#  [ 0 48  8  3  0]
#  [ 0 10 41  5  1]
#  [ 0  4  4 47  1]
#  [ 0  0  0  3  0]]
# 0.7696078431372549
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.72      0.84        29
#          1.0       0.75      0.81      0.78        59
#          2.0       0.69      0.72      0.71        57
#          3.0       0.81      0.84      0.82        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.77       204
#    macro avg       0.65      0.62      0.63       204
# weighted avg       0.78      0.77      0.77       204
#
# accuracy:  0.776979825353809
# accuracy:  0.6502380952380953
# col_0   0.0    1.0    2.0    3.0
# row_0
# 0.0    2830   1679   6861    554
# 1.0    1269  13624   5646   4642
# 2.0     982   2710  22305   1554
# 3.0     393   5707   3616  18583
# 4.0       9     77      3   1008
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.24      0.33     11924
#          1.0       0.57      0.54      0.56     25181
#          2.0       0.58      0.81      0.68     27551
#          3.0       0.71      0.66      0.68     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.61     94052
#    macro avg       0.47      0.45      0.45     94052
# weighted avg       0.60      0.61      0.59     94052
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'relai_p', 'rms_p', 'seis_inv_s', 'rms_s', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='low', facies='normal')
B.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[18  4  6  0  1]
#  [ 0 49  7  3  0]
#  [ 0 10 39  7  1]
#  [ 0  5  4 46  1]
#  [ 0  0  0  3  0]]
# 0.7450980392156863
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.62      0.77        29
#          1.0       0.72      0.83      0.77        59
#          2.0       0.70      0.68      0.69        57
#          3.0       0.78      0.82      0.80        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.75       204
#    macro avg       0.64      0.59      0.61       204
# weighted avg       0.76      0.75      0.74       204
#
# accuracy:  0.7401084010840108
# accuracy:  0.6311904761904762
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    3146   1923   6274    581    0
# 1.0    1223  14079   5929   3950    0
# 2.0    1367   2764  22107   1313    0
# 3.0     343   6064   4320  17546   26
# 4.0      16     32      5   1044    0
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.26      0.35     11924
#          1.0       0.57      0.56      0.56     25181
#          2.0       0.57      0.80      0.67     27551
#          3.0       0.72      0.62      0.67     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.60     94052
#    macro avg       0.47      0.45      0.45     94052
# weighted avg       0.60      0.60      0.59     94052
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'relai_p', 'seis_inv_s', 'domfreq_s']
C = ML_classification(features, well_line='W0', resolution='low', facies='normal')
C.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[14  4  9  2  0]
#  [ 3 43  8  5  0]
#  [ 2 10 36  8  1]
#  [ 1 10  4 40  1]
#  [ 0  0  1  2  0]]
# 0.6519607843137255
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.48      0.57        29
#          1.0       0.64      0.73      0.68        59
#          2.0       0.62      0.63      0.63        57
#          3.0       0.70      0.71      0.71        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.65       204
#    macro avg       0.53      0.51      0.52       204
# weighted avg       0.65      0.65      0.65       204
#
# accuracy:  0.6711683227943389
# accuracy:  0.6307142857142857
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0     844   1959   8413    708    0
# 1.0    1709  13187   5502   4770   13
# 2.0    1415   3117  21366   1647    6
# 3.0     410   4901   3019  19730  239
# 4.0     319      7     24    747    0
#               precision    recall  f1-score   support
#
#          0.0       0.18      0.07      0.10     11924
#          1.0       0.57      0.52      0.55     25181
#          2.0       0.56      0.78      0.65     27551
#          3.0       0.71      0.70      0.71     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.59     94052
#    macro avg       0.40      0.41      0.40     94052
# weighted avg       0.55      0.59      0.56     94052
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'seis_inv_s']
D = ML_classification(features, well_line='W0', resolution='low', facies='normal')
D.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[11  8  7  3  0]
#  [ 3 45  3  8  0]
#  [ 7  8 33  9  0]
#  [ 0 12  8 36  0]
#  [ 0  0  0  3  0]]
# 0.6127450980392157
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.38      0.44        29
#          1.0       0.62      0.76      0.68        59
#          2.0       0.65      0.58      0.61        57
#          3.0       0.61      0.64      0.63        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.61       204
#    macro avg       0.48      0.47      0.47       204
# weighted avg       0.60      0.61      0.60       204
#
# accuracy:  0.5628425173140621
# accuracy:  0.6019047619047618
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    1126   2231   7684    882    1
# 1.0    2024  13172   5119   4860    6
# 2.0    2252   3434  20280   1581    4
# 3.0     542   6102   2536  18988  131
# 4.0       0     34     13   1047    3
#               precision    recall  f1-score   support
#
#          0.0       0.19      0.09      0.13     11924
#          1.0       0.53      0.52      0.53     25181
#          2.0       0.57      0.74      0.64     27551
#          3.0       0.69      0.67      0.68     28299
#          4.0       0.02      0.00      0.00      1097
#
#     accuracy                           0.57     94052
#    macro avg       0.40      0.41      0.40     94052
# weighted avg       0.54      0.57      0.55     94052
# No handles with labels found to put in legend.
