# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['seismic_p','relai_p', 'rms_p', 'domfreq_p', 'd2_p', 'seismic_s','relai_s', 'rms_s', 'domfreq_s', 'd2_s']
A = ML_classification(features, well_line='W0', resolution='low', facies='normal')
A.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[21  2  5  0  1]
#  [ 1 51  5  2  0]
#  [ 0 14 34  8  1]
#  [ 1  3  4 48  0]
#  [ 0  3  0  0  0]]
# 0.7549019607843137
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.72      0.81        29
#          1.0       0.70      0.86      0.77        59
#          2.0       0.71      0.60      0.65        57
#          3.0       0.83      0.86      0.84        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.75       204
#    macro avg       0.63      0.61      0.61       204
# weighted avg       0.76      0.75      0.75       204
#
# accuracy:  0.7597560975609756
# accuracy:  0.5866666666666667
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    3117   1969   6326    512    0
# 1.0    1076  13714   5138   5234   19
# 2.0    1451   3373  21056   1666    5
# 3.0     406   6944   3940  16981   28
# 4.0      76    194     14    810    3
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.26      0.35     11924
#          1.0       0.52      0.54      0.53     25181
#          2.0       0.58      0.76      0.66     27551
#          3.0       0.67      0.60      0.63     28299
#          4.0       0.05      0.00      0.01      1097
#
#     accuracy                           0.58     94052
#    macro avg       0.47      0.43      0.44     94052
# weighted avg       0.58      0.58      0.57     94052
# No handles with labels found to put in legend.

# %%
features=['seismic_p','relai_p', 'rms_p', 'domfreq_p', 'd2_p', 'relai_s', 'rms_s', 'domfreq_s']
A = ML_classification(features, well_line='W0', resolution='low', facies='normal')
A.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[21  3  4  0  1]
#  [ 1 52  4  2  0]
#  [ 0 12 37  7  1]
#  [ 1  3  6 46  0]
#  [ 0  1  0  2  0]]
# 0.7647058823529411
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.72      0.81        29
#          1.0       0.73      0.88      0.80        59
#          2.0       0.73      0.65      0.69        57
#          3.0       0.81      0.82      0.81        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.76       204
#    macro avg       0.64      0.62      0.62       204
# weighted avg       0.77      0.76      0.76       204
#
# accuracy:  0.7671484492622704
# accuracy:  0.5964285714285714
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    2989   1598   7001    336    0
# 1.0     941  12857   5960   5423    0
# 2.0    1086   3075  21962   1427    1
# 3.0     387   6266   4920  16716   10
# 4.0      48    349     20    680    0
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.25      0.34     11924
#          1.0       0.53      0.51      0.52     25181
#          2.0       0.55      0.80      0.65     27551
#          3.0       0.68      0.59      0.63     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.58     94052
#    macro avg       0.46      0.43      0.43     94052
# weighted avg       0.58      0.58      0.56     94052
# No handles with labels found to put in legend.

# %%
features=['relai_p', 'rms_p', 'domfreq_p', 'relai_s', 'rms_s', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='low', facies='normal')
B.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[20  3  6  0  0]
#  [ 1 48  7  3  0]
#  [ 0 15 37  5  0]
#  [ 0  6  4 46  0]
#  [ 0  0  0  3  0]]
# 0.7401960784313726
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.69      0.80        29
#          1.0       0.67      0.81      0.73        59
#          2.0       0.69      0.65      0.67        57
#          3.0       0.81      0.82      0.81        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.74       204
#    macro avg       0.62      0.59      0.60       204
# weighted avg       0.74      0.74      0.74       204
#
# accuracy:  0.7696476964769647
# accuracy:  0.645
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    4173   1438   5109   1204    0
# 1.0    1487  11446   6530   5718    0
# 2.0    3300   3256  19432   1563    0
# 3.0     435   7177   4164  16521    2
# 4.0      30     37      0   1030    0
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.35      0.39     11924
#          1.0       0.49      0.45      0.47     25181
#          2.0       0.55      0.71      0.62     27551
#          3.0       0.63      0.58      0.61     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.55     94052
#    macro avg       0.42      0.42      0.42     94052
# weighted avg       0.54      0.55      0.54     94052
# No handles with labels found to put in legend.

# %%
features=['relai_p', 'relai_s', 'rms_p', 'rms_s']
C = ML_classification(features, well_line='W0', resolution='low', facies='normal')
C.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[20  4  5  0  0]
#  [ 0 49  8  2  0]
#  [ 0 13 35  8  1]
#  [ 0  4  4 48  0]
#  [ 0  0  0  3  0]]
# 0.7450980392156863
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.69      0.82        29
#          1.0       0.70      0.83      0.76        59
#          2.0       0.67      0.61      0.64        57
#          3.0       0.79      0.86      0.82        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.75       204
#    macro avg       0.63      0.60      0.61       204
# weighted avg       0.75      0.75      0.74       204
#
# accuracy:  0.7081150255947004
# accuracy:  0.6014285714285714
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    4550   1834   5075    463    2
# 1.0    1664  11858   6479   5174    6
# 2.0    6441   3291  16074   1744    1
# 3.0     620   6579   4147  16938   15
# 4.0       0    623     23    451    0
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.38      0.36     11924
#          1.0       0.49      0.47      0.48     25181
#          2.0       0.51      0.58      0.54     27551
#          3.0       0.68      0.60      0.64     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.53     94052
#    macro avg       0.40      0.41      0.40     94052
# weighted avg       0.53      0.53      0.53     94052
# No handles with labels found to put in legend.

# %%
features=['relai_p', 'rms_s']
D = ML_classification(features, well_line='W0', resolution='low', facies='normal')
D.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[10  9 10  0  0]
#  [ 3 31 17  8  0]
#  [ 5 20 23  9  0]
#  [ 1  9  5 40  1]
#  [ 0  2  0  1  0]]
# 0.5098039215686274
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.34      0.42        29
#          1.0       0.44      0.53      0.48        59
#          2.0       0.42      0.40      0.41        57
#          3.0       0.69      0.71      0.70        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.51       204
#    macro avg       0.41      0.40      0.40       204
# weighted avg       0.51      0.51      0.50       204
#
# accuracy:  0.5011743450767842
# accuracy:  0.4647619047619048
# col_0   0.0   1.0    2.0    3.0  4.0
# row_0
# 0.0    1246  2696   7588    393    1
# 1.0    1286  9528   7072   7291    4
# 2.0    1431  3885  20526   1708    1
# 3.0     540  6361   4069  17300   29
# 4.0       0   105     34    957    1
#               precision    recall  f1-score   support
#
#          0.0       0.28      0.10      0.15     11924
#          1.0       0.42      0.38      0.40     25181
#          2.0       0.52      0.75      0.61     27551
#          3.0       0.63      0.61      0.62     28299
#          4.0       0.03      0.00      0.00      1097
#
#     accuracy                           0.52     94052
#    macro avg       0.37      0.37      0.36     94052
# weighted avg       0.49      0.52      0.49     94052
# No handles with labels found to put in legend.
