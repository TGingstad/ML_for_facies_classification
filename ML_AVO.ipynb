# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['AVO_4_imp', 'AVO_4_shear', 'AVO_4_density']
A = ML_classification(features, well_line='W0', resolution='low', facies='normal')
A.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[14  9  5  1  0]
#  [ 2 40 12  4  1]
#  [ 5  7 32 13  0]
#  [ 0  9  6 41  0]
#  [ 0  1  0  2  0]]
# 0.6225490196078431
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.48      0.56        29
#          1.0       0.61      0.68      0.64        59
#          2.0       0.58      0.56      0.57        57
#          3.0       0.67      0.73      0.70        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.62       204
#    macro avg       0.51      0.49      0.49       204
# weighted avg       0.62      0.62      0.62       204
#
# accuracy:  0.6848087925323697
# accuracy:  0.6269047619047619
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# ...

# %%
features=['seis_inv_p', 'AVO_4_shear', 'AVO_4_density']
B = ML_classification(features, well_line='W0', resolution='low', facies='normal')
B.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[15  4  7  3  0]
#  [ 1 43  8  7  0]
#  [ 4 10 32 11  0]
#  [ 1 13  2 40  0]
#  [ 0  2  0  1  0]]
# 0.6372549019607843
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.52      0.60        29
#          1.0       0.60      0.73      0.66        59
#          2.0       0.65      0.56      0.60        57
#          3.0       0.65      0.71      0.68        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.64       204
#    macro avg       0.52      0.50      0.51       204
# weighted avg       0.63      0.64      0.63       204
#
# accuracy:  0.6330773863294189
# accuracy:  0.5726190476190476
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# ...

# %%
features=['AVO_4_imp', 'AVO_4_shear', 'AVO_4_density', 'relai_p', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='low', facies='normal')
B.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[20  1  7  1  0]
#  [ 1 44  8  5  1]
#  [ 3  7 35 12  0]
#  [ 1  5  3 46  1]
#  [ 0  0  0  3  0]]
# 0.7107843137254902
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.69      0.74        29
#          1.0       0.77      0.75      0.76        59
#          2.0       0.66      0.61      0.64        57
#          3.0       0.69      0.82      0.75        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.71       204
#    macro avg       0.58      0.57      0.58       204
# weighted avg       0.71      0.71      0.71       204
#
# accuracy:  0.7450617283950618
# accuracy:  0.615952380952381
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# ...

# %%
features=['AVO_4_imp', 'relai_p', 'domfreq_s']
D = ML_classification(features, well_line='W0', resolution='low', facies='normal')
D.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[14  5  9  1  0]
#  [ 2 42  9  6  0]
#  [ 6 12 25 13  1]
#  [ 1  4  4 46  1]
#  [ 0  0  0  3  0]]
# 0.6225490196078431
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.48      0.54        29
#          1.0       0.67      0.71      0.69        59
#          2.0       0.53      0.44      0.48        57
#          3.0       0.67      0.82      0.74        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.62       204
#    macro avg       0.49      0.49      0.49       204
# weighted avg       0.61      0.62      0.61       204
#
# accuracy:  0.6503462812405901
# accuracy:  0.6019047619047619
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# ...
