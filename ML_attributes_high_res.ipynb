# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['seismic_p','relai_p', 'rms_p', 'domfreq_p', 'd2_p', 'seismic_s','relai_s', 'rms_s', 'domfreq_s', 'd2_s']
A = ML_classification(features, well_line='W0', resolution='high', facies='normal')
A.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[23  2  4  0  0]
#  [ 2 45  7  5  0]
#  [ 2 16 39  0  0]
#  [ 1  8  5 42  0]
#  [ 0  0  0  3  0]]
# 0.7303921568627451
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.79      0.81        29
#          1.0       0.63      0.76      0.69        59
#          2.0       0.71      0.68      0.70        57
#          3.0       0.84      0.75      0.79        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.73       204
#    macro avg       0.60      0.60      0.60       204
# weighted avg       0.73      0.73      0.73       204
#
# accuracy:  0.7831376091538693
# accuracy:  0.65
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    3496    983   7146    299    0
# ...

# %%
features=['seismic_p','relai_p', 'rms_p', 'domfreq_p', 'd2_p', 'relai_s', 'rms_s', 'domfreq_s']
A = ML_classification(features, well_line='W0', resolution='high', facies='normal')
A.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[24  2  3  0  0]
#  [ 2 44  5  8  0]
#  [ 2 15 39  1  0]
#  [ 1 10  4 41  0]
#  [ 0  0  0  3  0]]
# 0.7254901960784313
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.83      0.83        29
#          1.0       0.62      0.75      0.68        59
#          2.0       0.76      0.68      0.72        57
#          3.0       0.77      0.73      0.75        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.73       204
#    macro avg       0.60      0.60      0.60       204
# weighted avg       0.72      0.73      0.72       204
#
# accuracy:  0.7819783197831978
# accuracy:  0.6414285714285715
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# ...

# %%
features=['relai_p', 'rms_p', 'domfreq_p', 'relai_s', 'rms_s', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='high', facies='normal')
B.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[24  3  2  0  0]
#  [ 1 45 10  3  0]
#  [ 2 12 40  3  0]
#  [ 1  6  6 43  0]
#  [ 0  0  0  3  0]]
# 0.7450980392156863
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.83      0.84        29
#          1.0       0.68      0.76      0.72        59
#          2.0       0.69      0.70      0.70        57
#          3.0       0.83      0.77      0.80        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.75       204
#    macro avg       0.61      0.61      0.61       204
# weighted avg       0.74      0.75      0.74       204
#
# accuracy:  0.7622704004817826
# accuracy:  0.6114285714285714
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# ...

# %%
features=['relai_p', 'relai_s', 'rms_p', 'rms_s']
C = ML_classification(features, well_line='W0', resolution='high', facies='normal')
C.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[16  7  5  1  0]
#  [ 4 39 10  6  0]
#  [ 3 15 36  3  0]
#  [ 0  7  7 41  1]
#  [ 0  0  0  3  0]]
# 0.6470588235294118
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.55      0.62        29
#          1.0       0.57      0.66      0.61        59
#          2.0       0.62      0.63      0.63        57
#          3.0       0.76      0.73      0.75        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.65       204
#    macro avg       0.53      0.52      0.52       204
# weighted avg       0.65      0.65      0.64       204
#
# accuracy:  0.677295995182174
# accuracy:  0.5964285714285713
# col_0   0.0   1.0    2.0    3.0  4.0
# row_0
# ...

# %%
features=['relai_p', 'rms_s']
D = ML_classification(features, well_line='W0', resolution='high', facies='normal')
D.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[ 9 11  9  0  0]
#  [ 6 28 16  9  0]
#  [ 5 16 32  4  0]
#  [ 2 15  3 35  1]
#  [ 0  1  0  2  0]]
# 0.5098039215686274
#               precision    recall  f1-score   support
#
#          0.0       0.41      0.31      0.35        29
#          1.0       0.39      0.47      0.43        59
#          2.0       0.53      0.56      0.55        57
#          3.0       0.70      0.62      0.66        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.51       204
#    macro avg       0.41      0.39      0.40       204
# weighted avg       0.51      0.51      0.51       204
#
# accuracy:  0.511156278229449
# accuracy:  0.47071428571428575
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# ...
