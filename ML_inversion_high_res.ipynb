# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['seis_inv_p', 'relai_p', 'rms_p', 'domfreq_p', 'seis_inv_s', 'relai_s', 'rms_s', 'domfreq_s']
A = ML_classification(features, well_line='W0', resolution='high', facies='normal')
A.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[24  2  2  1  0]
#  [ 1 47  6  5  0]
#  [ 1 15 37  4  0]
#  [ 0  3  2 51  0]
#  [ 0  0  0  3  0]]
# 0.7794117647058824
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.83      0.87        29
#          1.0       0.70      0.80      0.75        59
#          2.0       0.79      0.65      0.71        57
#          3.0       0.80      0.91      0.85        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.78       204
#    macro avg       0.64      0.64      0.64       204
# weighted avg       0.77      0.78      0.77       204
#
# accuracy:  0.7856970791930141
# accuracy:  0.6321428571428572
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    3012   1324   7287    301    0
# 1.0    1705  13223   5044   5209    0
# 2.0     769   2706  23440    626   10
# 3.0     492   4530   2743  20519   15
# 4.0       0     35      2   1059    1
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.25      0.34     11924
#          1.0       0.61      0.53      0.56     25181
#          2.0       0.61      0.85      0.71     27551
#          3.0       0.74      0.73      0.73     28299
#          4.0       0.04      0.00      0.00      1097
#
#     accuracy                           0.64     94052
#    macro avg       0.50      0.47      0.47     94052
# weighted avg       0.63      0.64      0.62     94052
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'relai_p', 'rms_p', 'seis_inv_s', 'rms_s', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='high', facies='normal')
B.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[21  5  3  0  0]
#  [ 2 42  8  7  0]
#  [ 2 15 37  3  0]
#  [ 0  5  1 50  0]
#  [ 0  0  0  3  0]]
# 0.7352941176470589
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.72      0.78        29
#          1.0       0.63      0.71      0.67        59
#          2.0       0.76      0.65      0.70        57
#          3.0       0.79      0.89      0.84        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.74       204
#    macro avg       0.60      0.60      0.60       204
# weighted avg       0.73      0.74      0.73       204
#
# accuracy:  0.7697229750075278
# accuracy:  0.6114285714285714
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    2991   1400   7191    342    0
# 1.0    1603  13487   5238   4853    0
# 2.0     588   2751  23546    666    0
# 3.0     660   4815   2866  19956    2
# 4.0       0     20      8   1069    0
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.25      0.34     11924
#          1.0       0.60      0.54      0.57     25181
#          2.0       0.61      0.85      0.71     27551
#          3.0       0.74      0.71      0.72     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.64     94052
#    macro avg       0.49      0.47      0.47     94052
# weighted avg       0.63      0.64      0.62     94052
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'relai_p', 'seis_inv_s', 'domfreq_s']
C = ML_classification(features, well_line='W0', resolution='high', facies='normal')
C.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[16  3 10  0  0]
#  [ 3 39  9  8  0]
#  [ 5 11 38  3  0]
#  [ 0  8  0 48  0]
#  [ 0  0  0  3  0]]
# 0.6911764705882353
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.55      0.60        29
#          1.0       0.64      0.66      0.65        59
#          2.0       0.67      0.67      0.67        57
#          3.0       0.77      0.86      0.81        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.69       204
#    macro avg       0.55      0.55      0.55       204
# weighted avg       0.68      0.69      0.68       204
#
# accuracy:  0.6724330021077988
# accuracy:  0.5576190476190476
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    1906   2587   6988    443    0
# 1.0    1777  13620   4294   5482    8
# 2.0    1106   3510  21859   1075    1
# 3.0     485   5713   2277  19788   36
# 4.0       0      7      1   1089    0
#               precision    recall  f1-score   support
#
#          0.0       0.36      0.16      0.22     11924
#          1.0       0.54      0.54      0.54     25181
#          2.0       0.62      0.79      0.69     27551
#          3.0       0.71      0.70      0.70     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.61     94052
#    macro avg       0.44      0.44      0.43     94052
# weighted avg       0.58      0.61      0.59     94052
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'seis_inv_s']
D = ML_classification(features, well_line='W0', resolution='high', facies='normal')
D.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[11  2 12  4  0]
#  [ 5 34 10 10  0]
#  [ 8 16 28  5  0]
#  [ 1 16  3 36  0]
#  [ 0  0  0  3  0]]
# 0.5343137254901961
#               precision    recall  f1-score   support
#
#          0.0       0.44      0.38      0.41        29
#          1.0       0.50      0.58      0.54        59
#          2.0       0.53      0.49      0.51        57
#          3.0       0.62      0.64      0.63        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.53       204
#    macro avg       0.42      0.42      0.42       204
# weighted avg       0.53      0.53      0.53       204
#
# accuracy:  0.580081300813008
# accuracy:  0.529047619047619
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    1941   2287   7049    642    5
# 1.0    2518  15294   4318   3048    3
# 2.0    1422   3473  21711    943    2
# 3.0     715   7149   4250  15825  360
# 4.0       1    111     28    956    1
#               precision    recall  f1-score   support
#
#          0.0       0.29      0.16      0.21     11924
#          1.0       0.54      0.61      0.57     25181
#          2.0       0.58      0.79      0.67     27551
#          3.0       0.74      0.56      0.64     28299
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.58     94052
#    macro avg       0.43      0.42      0.42     94052
# weighted avg       0.57      0.58      0.57     94052
# No handles with labels found to put in legend.
