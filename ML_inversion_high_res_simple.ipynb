# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['seis_inv_p', 'relai_p', 'rms_p', 'domfreq_p', 'seis_inv_s', 'relai_s', 'rms_s', 'domfreq_s']
A = ML_classification(features, well_line='W0', resolution='high', facies='simple')
A.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[134   6   0]
#  [ 16  45   0]
#  [  0   3   0]]
# 0.8774509803921569
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.96      0.92       140
#          3.0       0.83      0.74      0.78        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.88       204
#    macro avg       0.58      0.56      0.57       204
# weighted avg       0.86      0.88      0.87       204
#
# accuracy:  0.8855164107196627
# accuracy:  0.8621428571428572
# col_0    0.0    3.0  4.0
# row_0
# 0.0    60897   3542    0
# 3.0    12158  16355    2
# 4.0       39   1058    0
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.89     64439
#          3.0       0.78      0.57      0.66     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.82     94051
#    macro avg       0.54      0.51      0.52     94051
# weighted avg       0.81      0.82      0.81     94051
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'relai_p', 'rms_p', 'seis_inv_s', 'rms_s', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='high', facies='simple')
B.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[134   6   0]
#  [ 13  48   0]
#  [  0   3   0]]
# 0.8921568627450981
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.96      0.93       140
#          3.0       0.84      0.79      0.81        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.89       204
#    macro avg       0.58      0.58      0.58       204
# weighted avg       0.88      0.89      0.88       204
#
# accuracy:  0.8928334838903943
# accuracy:  0.8576190476190476
# col_0    0.0    3.0  4.0
# row_0
# 0.0    59877   4558    4
# 3.0    11792  16711   12
# 4.0       19   1078    0
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.93      0.88     64439
#          3.0       0.75      0.59      0.66     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.81     94051
#    macro avg       0.53      0.51      0.51     94051
# weighted avg       0.80      0.81      0.80     94051
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'relai_p', 'seis_inv_s', 'rms_s']
C = ML_classification(features, well_line='W0', resolution='high', facies='simple')
C.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[130  10   0]
#  [ 12  49   0]
#  [  0   3   0]]
# 0.8774509803921569
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.93      0.92       140
#          3.0       0.79      0.80      0.80        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.88       204
#    macro avg       0.57      0.58      0.57       204
# weighted avg       0.86      0.88      0.87       204
#
# accuracy:  0.8694519722975007
# accuracy:  0.8526190476190477
# col_0    0.0    3.0  4.0
# row_0
# 0.0    59686   4753    0
# 3.0    11625  16846   44
# 4.0       42   1055    0
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.93      0.88     64439
#          3.0       0.74      0.59      0.66     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.81     94051
#    macro avg       0.53      0.51      0.51     94051
# weighted avg       0.80      0.81      0.80     94051
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'seis_inv_s']
D = ML_classification(features, well_line='W0', resolution='high', facies='simple')
D.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[130  10   0]
#  [ 23  38   0]
#  [  0   3   0]]
# 0.8235294117647058
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.93      0.89       140
#          3.0       0.75      0.62      0.68        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.82       204
#    macro avg       0.53      0.52      0.52       204
# weighted avg       0.81      0.82      0.81       204
#
# accuracy:  0.8190454682324602
# accuracy:  0.8235714285714286
# col_0    0.0    3.0  4.0
# row_0
# 0.0    60543   3867   29
# 3.0    12801  15037  677
# 4.0      110    985    2
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.94      0.88     64439
#          3.0       0.76      0.53      0.62     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.80     94051
#    macro avg       0.53      0.49      0.50     94051
# weighted avg       0.79      0.80      0.79     94051
# No handles with labels found to put in legend.
