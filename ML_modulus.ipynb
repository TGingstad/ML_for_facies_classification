# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['Bulk', 'Shear', 'Poisson', 'Youngs']
A = ML_classification(features, well_line='W0', resolution='low', facies='normal')
A.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[15  4  6  3  1]
#  [11 37  7  3  1]
#  [12 10 22 12  1]
#  [ 1  4  7 43  1]
#  [ 0  0  0  2  1]]
# 0.5784313725490197
#               precision    recall  f1-score   support
#
#          0.0       0.38      0.52      0.44        29
#          1.0       0.67      0.63      0.65        59
#          2.0       0.52      0.39      0.44        57
#          3.0       0.68      0.77      0.72        56
#          4.0       0.20      0.33      0.25         3
#
#     accuracy                           0.58       204
#    macro avg       0.49      0.53      0.50       204
# weighted avg       0.59      0.58      0.58       204
#
# accuracy:  0.5333333333333332
# accuracy:  0.5926190476190476
# col_0   0.0   1.0    2.0    3.0  4.0
# row_0
# 0.0    2658  3320   5114    832    0
# 1.0    5202  6192  10658   3109   20
# 2.0    3809  9226  11291   3205   20
# 3.0     446  2064   4629  21137   23
# 4.0       9    76     56    783  173
#               precision    recall  f1-score   support
#
#          0.0       0.22      0.22      0.22     11924
#          1.0       0.30      0.25      0.27     25181
#          2.0       0.36      0.41      0.38     27551
#          3.0       0.73      0.75      0.74     28299
#          4.0       0.73      0.16      0.26      1097
#
#     accuracy                           0.44     94052
#    macro avg       0.47      0.36      0.37     94052
# weighted avg       0.44      0.44      0.44     94052
# No handles with labels found to put in legend.

# %%
features=['Bulk', 'Shear', 'Poisson', 'Youngs', 'relai_p', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='low', facies='normal')
B.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[16  3  8  1  1]
#  [ 1 47  6  5  0]
#  [ 5  7 33 11  1]
#  [ 0  4  7 44  1]
#  [ 0  0  0  2  1]]
# 0.6911764705882353
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.55      0.63        29
#          1.0       0.77      0.80      0.78        59
#          2.0       0.61      0.58      0.59        57
#          3.0       0.70      0.79      0.74        56
#          4.0       0.25      0.33      0.29         3
#
#     accuracy                           0.69       204
#    macro avg       0.61      0.61      0.61       204
# weighted avg       0.69      0.69      0.69       204
#
# accuracy:  0.7230051189400781
# accuracy:  0.6702380952380953
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    3236   1609   6439    616   24
# 1.0    1992  14015   6586   2553   35
# 2.0    2615   3158  19628   2119   31
# 3.0     310   1974   3428  22561   26
# 4.0       1     12     18    722  344
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.27      0.32     11924
#          1.0       0.67      0.56      0.61     25181
#          2.0       0.54      0.71      0.62     27551
#          3.0       0.79      0.80      0.79     28299
#          4.0       0.75      0.31      0.44      1097
#
#     accuracy                           0.64     94052
#    macro avg       0.63      0.53      0.56     94052
# weighted avg       0.64      0.64      0.63     94052
# No handles with labels found to put in legend.

# %%
features=['Poisson', 'relai_p', 'domfreq_s']
C = ML_classification(features, well_line='W0', resolution='low', facies='normal')
C.run_results()
# Out:
#      1    192  451
# 0.0   63   36   31
# 1.0  157  101   59
# 2.0   58  132  128
# 3.0   69   82   92
# 4.0    3    2    3
# 2.0    318
# 1.0    317
# 3.0    243
# 0.0    130
# 4.0      8
# Name: facies, dtype: int64
# [[14  3 11  1  0]
#  [ 1 45  8  5  0]
#  [ 4  8 32 12  1]
#  [ 0  5  5 45  1]
#  [ 0  0  0  3  0]]
# 0.6666666666666666
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.48      0.58        29
#          1.0       0.74      0.76      0.75        59
#          2.0       0.57      0.56      0.57        57
#          3.0       0.68      0.80      0.74        56
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.67       204
#    macro avg       0.55      0.52      0.53       204
# weighted avg       0.66      0.67      0.66       204
#
# accuracy:  0.6786058416139716
# accuracy:  0.577857142857143
# col_0   0.0    1.0    2.0    3.0  4.0
# row_0
# 0.0    1945   1386   7987    591   15
# 1.0    1551  13974   7117   2530    9
# 2.0    2574   3709  19403   1865    0
# 3.0     284   2733   4684  20593    5
# 4.0       0     13     82    994    8
#               precision    recall  f1-score   support
#
#          0.0       0.31      0.16      0.21     11924
#          1.0       0.64      0.55      0.59     25181
#          2.0       0.49      0.70      0.58     27551
#          3.0       0.77      0.73      0.75     28299
#          4.0       0.22      0.01      0.01      1097
#
#     accuracy                           0.59     94052
#    macro avg       0.49      0.43      0.43     94052
# weighted avg       0.59      0.59      0.58     94052
# No handles with labels found to put in legend.
