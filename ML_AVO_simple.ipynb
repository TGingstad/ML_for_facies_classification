# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['AVO_4_imp', 'AVO_4_shear', 'AVO_4_density']
A = ML_classification(features, well_line='W0', resolution='low', facies='simple')
A.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[125  14   1]
#  [ 17  44   0]
#  [  2   1   0]]
# 0.8284313725490197
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88       140
#          3.0       0.75      0.72      0.73        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.83       204
#    macro avg       0.54      0.54      0.54       204
# weighted avg       0.82      0.83      0.82       204
#
# accuracy:  0.8866757000903341
# accuracy:  0.8426190476190477
# col_0    0.0    3.0  4.0
# row_0
# 0.0    59653   4736   50
# 3.0     7957  20546   12
# 4.0      161    920   16
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.93      0.90     64439
#          3.0       0.78      0.72      0.75     28515
#          4.0       0.21      0.01      0.03      1097
#
#     accuracy                           0.85     94051
#    macro avg       0.62      0.55      0.56     94051
# weighted avg       0.84      0.85      0.85     94051
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'AVO_4_shear', 'AVO_4_density']
B = ML_classification(features, well_line='W0', resolution='low', facies='simple')
B.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[124  16   0]
#  [ 20  41   0]
#  [  2   1   0]]
# 0.8088235294117647
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.89      0.87       140
#          3.0       0.71      0.67      0.69        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.81       204
#    macro avg       0.52      0.52      0.52       204
# weighted avg       0.79      0.81      0.80       204
#
# accuracy:  0.8361788617886179
# accuracy:  0.8433333333333334
# col_0    0.0    3.0  4.0
# row_0
# 0.0    58084   6336   19
# 3.0    11365  17128   22
# 4.0      147    946    4
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.90      0.87     64439
#          3.0       0.70      0.60      0.65     28515
#          4.0       0.09      0.00      0.01      1097
#
#     accuracy                           0.80     94051
#    macro avg       0.54      0.50      0.51     94051
# weighted avg       0.79      0.80      0.79     94051
# No handles with labels found to put in legend.

# %%
features=['AVO_4_imp', 'AVO_4_shear', 'AVO_4_density', 'relai_p', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='low', facies='simple')
B.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[126  13   1]
#  [ 13  47   1]
#  [  1   2   0]]
# 0.8480392156862745
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.90      0.90       140
#          3.0       0.76      0.77      0.76        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.85       204
#    macro avg       0.55      0.56      0.55       204
# weighted avg       0.84      0.85      0.85       204
#
# accuracy:  0.894068051791629
# accuracy:  0.8526190476190475
# col_0    0.0    3.0  4.0
# row_0
# 0.0    59360   5019   60
# 3.0     5814  22692    9
# 4.0       28   1002   67
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.92      0.92     64439
#          3.0       0.79      0.80      0.79     28515
#          4.0       0.49      0.06      0.11      1097
#
#     accuracy                           0.87     94051
#    macro avg       0.73      0.59      0.61     94051
# weighted avg       0.87      0.87      0.87     94051
# No handles with labels found to put in legend.

# %%
features=['AVO_4_imp', 'relai_p', 'domfreq_s']
D = ML_classification(features, well_line='W0', resolution='low', facies='simple')
D.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[127  13   0]
#  [ 12  47   2]
#  [  0   3   0]]
# 0.8529411764705882
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.91      0.91       140
#          3.0       0.75      0.77      0.76        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.85       204
#    macro avg       0.55      0.56      0.56       204
# weighted avg       0.85      0.85      0.85       204
#
# accuracy:  0.8842366757000903
# accuracy:  0.8285714285714285
# col_0    0.0    3.0  4.0
# row_0
# 0.0    59308   5097   34
# 3.0     6248  22263    4
# 4.0       13   1049   35
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.92      0.91     64439
#          3.0       0.78      0.78      0.78     28515
#          4.0       0.48      0.03      0.06      1097
#
#     accuracy                           0.87     94051
#    macro avg       0.72      0.58      0.58     94051
# weighted avg       0.86      0.87      0.86     94051
# No handles with labels found to put in legend.
