# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['seis_inv_p', 'relai_p', 'rms_p', 'domfreq_p', 'seis_inv_s', 'relai_s', 'rms_s', 'domfreq_s']
A = ML_classification(features, well_line='W0', resolution='low', facies='simple')
A.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[134   6   0]
#  [ 19  42   0]
#  [  0   3   0]]
# 0.8627450980392157
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.96      0.91       140
#          3.0       0.82      0.69      0.75        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.86       204
#    macro avg       0.57      0.55      0.55       204
# weighted avg       0.85      0.86      0.85       204
#
# accuracy:  0.8743300210779885
# accuracy:  0.824047619047619
# col_0    0.0    3.0
# row_0
# 0.0    59425   5014
# 3.0    12212  16303
# 4.0      405    692
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.92      0.87     64439
#          3.0       0.74      0.57      0.65     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.81     94051
#    macro avg       0.52      0.50      0.51     94051
# weighted avg       0.79      0.81      0.79     94051
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'relai_p', 'rms_p', 'seis_inv_s', 'rms_s', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='low', facies='simple')
B.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[133   7   0]
#  [ 15  44   2]
#  [  0   3   0]]
# 0.8676470588235294
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.95      0.92       140
#          3.0       0.81      0.72      0.77        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.87       204
#    macro avg       0.57      0.56      0.56       204
# weighted avg       0.86      0.87      0.86       204
#
# accuracy:  0.8768142125865703
# accuracy:  0.8185714285714285
# col_0    0.0    3.0  4.0
# row_0
# 0.0    59779   4660    0
# 3.0    12673  15838    4
# 4.0       79   1018    0
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.93      0.87     64439
#          3.0       0.74      0.56      0.63     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.80     94051
#    macro avg       0.52      0.49      0.50     94051
# weighted avg       0.79      0.80      0.79     94051
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'relai_p', 'seis_inv_s', 'domfreq_s']
C = ML_classification(features, well_line='W0', resolution='low', facies='simple')
C.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[126  14   0]
#  [ 21  38   2]
#  [  1   2   0]]
# 0.803921568627451
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.90      0.88       140
#          3.0       0.70      0.62      0.66        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.80       204
#    macro avg       0.52      0.51      0.51       204
# weighted avg       0.79      0.80      0.80       204
#
# accuracy:  0.864453477868112
# accuracy:  0.8328571428571427
# col_0    0.0    3.0  4.0
# row_0
# 0.0    57478   6957    4
# 3.0     8887  19543   85
# 4.0       76   1021    0
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88     64439
#          3.0       0.71      0.69      0.70     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.82     94051
#    macro avg       0.53      0.53      0.53     94051
# weighted avg       0.81      0.82      0.81     94051
# No handles with labels found to put in legend.

# %%
features=['seis_inv_p', 'seis_inv_s']
D = ML_classification(features, well_line='W0', resolution='low', facies='simple')
D.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[125  15   0]
#  [ 20  41   0]
#  [  0   3   0]]
# 0.8137254901960784
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.89      0.88       140
#          3.0       0.69      0.67      0.68        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.81       204
#    macro avg       0.52      0.52      0.52       204
# weighted avg       0.80      0.81      0.81       204
#
# accuracy:  0.8386329418849744
# accuracy:  0.8483333333333333
# col_0    0.0    3.0  4.0
# row_0
# 0.0    57043   7388    8
# 3.0     9257  19162   96
# 4.0       35   1060    2
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.89      0.87     64439
#          3.0       0.69      0.67      0.68     28515
#          4.0       0.02      0.00      0.00      1097
#
#     accuracy                           0.81     94051
#    macro avg       0.52      0.52      0.52     94051
# weighted avg       0.80      0.81      0.80     94051
# No handles with labels found to put in legend.
