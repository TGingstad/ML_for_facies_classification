# %%
import sys
sys.path.append('../ML_for_facies_classification/functions')

from ML_Class import ML_classification

# %%
features=['seismic_p','relai_p', 'rms_p', 'domfreq_p', 'd2_p', 'seismic_s','relai_s', 'rms_s', 'domfreq_s', 'd2_s']
A = ML_classification(features, well_line='W0', resolution='low', facies='simple')
A.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[132   7   1]
#  [ 19  42   0]
#  [  3   0   0]]
# 0.8529411764705882
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.94      0.90       140
#          3.0       0.86      0.69      0.76        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.85       204
#    macro avg       0.57      0.54      0.55       204
# weighted avg       0.84      0.85      0.84       204
#
# accuracy:  0.8755495332731105
# accuracy:  0.8338095238095239
# col_0    0.0    3.0  4.0
# row_0
# 0.0    60642   3792    5
# 3.0    16254  12251   10
# 4.0      567    529    1
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.94      0.85     64439
#          3.0       0.74      0.43      0.54     28515
#          4.0       0.06      0.00      0.00      1097
#
#     accuracy                           0.78     94051
#    macro avg       0.53      0.46      0.47     94051
# weighted avg       0.76      0.78      0.75     94051
# No handles with labels found to put in legend.

# %%
features=['seismic_p','relai_p', 'rms_p', 'domfreq_p', 'd2_p', 'relai_s', 'rms_s', 'domfreq_s']
A = ML_classification(features, well_line='W0', resolution='low', facies='simple')
A.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[134   6   0]
#  [ 21  40   0]
#  [  2   1   0]]
# 0.8529411764705882
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.96      0.90       140
#          3.0       0.85      0.66      0.74        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.85       204
#    macro avg       0.57      0.54      0.55       204
# weighted avg       0.84      0.85      0.84       204
#
# accuracy:  0.8657181571815717
# accuracy:  0.8235714285714286
# col_0    0.0    3.0  4.0
# row_0
# 0.0    60322   4116    1
# 3.0    17031  11478    6
# 4.0      603    494    0
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.94      0.85     64439
#          3.0       0.71      0.40      0.51     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.76     94051
#    macro avg       0.50      0.45      0.45     94051
# weighted avg       0.75      0.76      0.74     94051
# No handles with labels found to put in legend.

# %%
features=['relai_p', 'rms_p', 'domfreq_p', 'relai_s', 'rms_s', 'domfreq_s']
B = ML_classification(features, well_line='W0', resolution='low', facies='simple')
B.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[134   6   0]
#  [ 20  41   0]
#  [  0   3   0]]
# 0.8578431372549019
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.96      0.91       140
#          3.0       0.82      0.67      0.74        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.86       204
#    macro avg       0.56      0.54      0.55       204
# weighted avg       0.84      0.86      0.85       204
#
# accuracy:  0.8755645889792232
# accuracy:  0.8338095238095239
# col_0    0.0    3.0
# row_0
# 0.0    59342   5097
# 3.0    14215  14300
# 4.0      456    641
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.92      0.86     64439
#          3.0       0.71      0.50      0.59     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.78     94051
#    macro avg       0.51      0.47      0.48     94051
# weighted avg       0.77      0.78      0.77     94051
# No handles with labels found to put in legend.

# %%
features=['relai_p', 'relai_s', 'rms_p', 'rms_s']
C = ML_classification(features, well_line='W0', resolution='low', facies='simple')
C.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[132   8   0]
#  [ 17  44   0]
#  [  0   3   0]]
# 0.8627450980392157
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.94      0.91       140
#          3.0       0.80      0.72      0.76        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.86       204
#    macro avg       0.56      0.55      0.56       204
# weighted avg       0.85      0.86      0.85       204
#
# accuracy:  0.8460252935862691
# accuracy:  0.8335714285714285
# col_0    0.0    3.0  4.0
# row_0
# 0.0    58390   6043    6
# 3.0    13473  15027   15
# 4.0      638    459    0
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.91      0.85     64439
#          3.0       0.70      0.53      0.60     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.78     94051
#    macro avg       0.50      0.48      0.48     94051
# weighted avg       0.76      0.78      0.77     94051
# No handles with labels found to put in legend.

# %%
features=['relai_p', 'rms_s']
D = ML_classification(features, well_line='W0', resolution='low', facies='simple')
D.run_results()
# Out:
#      1    192  451
# 0.0  278  252  210
# 3.0   69   99  100
# 4.0    3    2    3
# 0.0    740
# 3.0    268
# 4.0      8
# Name: facies, dtype: int64
# [[126  14   0]
#  [ 23  38   0]
#  [  0   3   0]]
# 0.803921568627451
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.90      0.87       140
#          3.0       0.69      0.62      0.66        61
#          4.0       0.00      0.00      0.00         3
#
#     accuracy                           0.80       204
#    macro avg       0.51      0.51      0.51       204
# weighted avg       0.79      0.80      0.79       204
#
# accuracy:  0.7722071665161097
# accuracy:  0.7988095238095239
# col_0    0.0    3.0  4.0
# row_0
# 0.0    56036   8398    5
# 3.0    11867  16631   17
# 4.0      163    934    0
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.87      0.85     64439
#          3.0       0.64      0.58      0.61     28515
#          4.0       0.00      0.00      0.00      1097
#
#     accuracy                           0.77     94051
#    macro avg       0.49      0.48      0.49     94051
# weighted avg       0.76      0.77      0.76     94051
# No handles with labels found to put in legend.
